# %% [markdown]
# <a href="https://colab.research.google.com/github/encoras/Artificial-Intelligence-Group/blob/master/segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rembg

# %%
from rembg import remove
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow
img=Image.open('/content/drive/MyDrive/amber2023/Visi/NK02_cropped/Image.1.png')
out=remove(img)
out
# Out:
# ...
# 100%|███████████████████████████████████████| 176M/176M [00:00<00:00, 53.8GB/s]

# %%
img=Image.open('/content/drive/MyDrive/amber2023/Visi (1)/NK01_cropped/Image.1.png')
out=remove(img)
out
# Out:
# <PIL.Image.Image image mode=RGBA size=194x117 at 0x7FBA85E6C5B0>

# %%
pix = np.array(out)
a=pix[:,:,3]

# %%
cv2_imshow(a)
# Out:
# <PIL.Image.Image image mode=L size=194x117 at 0x7FBA85F3BC70>
